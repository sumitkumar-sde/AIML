# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 = cv2.imread('images/eiphel1.png')
img2 = cv2.imread('images/eiphel2.png')

# %%
plt.figure(figsize=(16,9))
plt.subplot(121)
plt.imshow(img1, cmap = 'gray')
plt.subplot(122)
plt.imshow(img2, cmap = 'gray')

# %%
sift = cv2.SIFT_create()

# %%
print(sift)
# Out:
# < cv2.SIFT 0000026C10AF8A10>

# %%
keypoints_1, description_1 = sift.detectAndCompute(img1, None)
keypoints_2, description_2 = sift.detectAndCompute(img2, None)

# %%
len(keypoints_1), len(keypoints_2)
# Out:
# (332, 404)

# %%
bf = cv2.BFMatcher(cv2.NORM_L1)

matches = bf.match(description_1, description_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 =  cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:20], img2, flags = 2)

# %%
plt.imshow(img3)

# %% [markdown]
# # Copy any image to any image

# %%
img1H = img1.shape[0]
img2H = img2.shape[0]
img1W = img1.shape[1]
img2W = img2.shape[1]

# %%
img1H, img2H, img1W, img1W
# Out:
# (293, 178, 198, 198)

# %%
imgFH = (lambda: img1H, lambda: img2H)[img2H > img1H]()
imgFW = (lambda: img1W, lambda: img2W)[img2W > img1W]()

# %%
imgF = np.zero([

# %%
a = 10
b = 20

(lambda: b, lambda: a)[a < b]()
# Out:
# 10
