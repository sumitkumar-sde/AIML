# %%
import pandas as pd
import numpy as np

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
s = pd.Series([45,22,17,3,33,16,8,5], dtype = np.int8)
s[4]= 23

# %%
s, s.shape, s.size
# Out:
# (0    45
#  1    22
#  2    17
#  3     3
#  4    23
#  5    16
#  6     8
#  7     5
#  dtype: int8,
#  (8,),
#  8)

# %%
roll = pd.Series([1,2,3,4,5])
name = pd.Series(['Nitin','Sumit','Rani','Anjali','Smita'])
marks = pd.Series([60,50.5,45,78,96.5])

# %%
df = pd.DataFrame({
    'Roll':roll,
    'Name':name,
    'Marks':marks
})

# %%
df, df.dtypes, df.shape, df.size
# Out:
# (   Roll    Name  Marks
#  0     1   Nitin   60.0
#  1     2   Sumit   50.5
#  2     3    Rani   45.0
#  3     4  Anjali   78.0
#  4     5   Smita   96.5,
#  Roll       int64
#  Name      object
#  Marks    float64
#  dtype: object,
#  (5, 3),
#  15)

# %%
df.dtypes
# Out:
# Roll       int64
# Name      object
# Marks    float64
# dtype: object

# %%
5231/226
# Out:
# 23.146017699115045

# %% [markdown]
# # Loads the Data

# %%
datas = pd.read_csv('Datasets/Students/student.csv')

# %%
datas
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
datas.size, datas.shape, datas.values
# Out:
# (50,
#  (10, 5),
#  array([[1, 'anil', 'TE', 56.77, 22],
#         [2, 'amit', 'TE', 59.77, 21],
#         [3, 'aniket', 'BE', 76.88, 19],
#         [4, 'ajinkya', 'TE', 69.66, 20],
#         [5, 'asha', 'TE', 63.28, 20],
#         [6, 'ayesha', 'BE', 49.55, 20],
#         [7, 'amar', 'BE', 65.34, 19],
#         [8, 'amita', 'BE', 68.33, 23],
#         [9, 'amol', 'TE', 56.75, 20],
#         [10, 'anmol', 'BE', 78.66, 21]], dtype=object))

# %%
data_1 = pd.read_csv('Datasets/Students/student1.csv')

# %%
data_1
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %% [markdown]
# ### Header Names

# %%
data_1 = pd.read_csv('Datasets/Students/student1.csv', names =[ 'A','B', 'C', 'D', 'E', 'F'] )
data_1
# Out:
#     A        B   C      D   E   F
# 0   1     anil  TE  56.77  22 NaN
# 1   2     amit  TE  59.77  21 NaN
# 2   3   aniket  BE  76.88  19 NaN
# 3   4  ajinkya  TE  69.66  20 NaN
# 4   5     asha  TE  63.28  20 NaN
# 5   6   ayesha  BE  49.55  20 NaN
# 6   7     amar  BE  65.34  19 NaN
# 7   8    amita  BE  68.33  23 NaN
# 8   9     amol  TE  56.75  20 NaN
# 9  10    anmol  BE  78.66  21 NaN

# %%
print(data_1['F'])
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: F, dtype: float64

# %%
data_12 = pd.read_csv('Datasets/Students/student1.csv', header = None)
data_12
# Out:
#     0        1   2      3   4
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
data_12 = pd.read_csv('Datasets/Students/student1.csv', names = None)
data_12
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
data_2 = pd.read_csv('Datasets/Students/student3.tsv', sep = '\t')
data_2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
data_2 = pd.read_table('Datasets/Students/student3.tsv')
data_2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %% [markdown]
# # Acess the Data in Raw Form

# %%
iris_data = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
iris_data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris_data.size
# Out:
# 750

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_data.shape
# Out:
# (150, 5)

# %%
data_2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
data_2.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
data_2.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
data_2.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %% [markdown]
# # Slicing
# ### Name Based Slicing
# ### Index Based Slicing

# %%
data_21 = data_2.iloc[:, :2]
data_21
# Out:
#    roll     name
# 0     1     anil
# 1     2     amit
# 2     3   aniket
# 3     4  ajinkya
# 4     5     asha
# 5     6   ayesha
# 6     7     amar
# 7     8    amita
# 8     9     amol
# 9    10    anmol

# %%
help(data_21.loc)
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Access a group of rows and columns by label(s) or a boolean array.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'``.
#  |
#  |    .. warning:: Note that contrary to usual python slices, **both** the
#  |        start and the stop are included
#  |
#  |  - A boolean array of the same length as the axis being sliced,
#  |    e.g. ``[True, False, True]``.
#  |  - An alignable boolean Series. The index of the key will be aligned before
#  |    masking.
# ...

# %%
data_2.iloc[:,[1, 0]]
# Out:
#       name  roll
# 0     anil     1
# 1     amit     2
# 2   aniket     3
# 3  ajinkya     4
# 4     asha     5
# 5   ayesha     6
# 6     amar     7
# 7    amita     8
# 8     amol     9
# 9    anmol    10

# %% [markdown]
# #### To Acess single item of the List

# %%
data_2.iloc[3,4]
# Out:
# 20

# %% [markdown]
# #### Label Based Slicing

# %%
data_2.loc[:,['name', 'marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
data_2.name.values
# Out:
# array(['anil', 'amit', 'aniket', 'ajinkya', 'asha', 'ayesha', 'amar',
#        'amita', 'amol', 'anmol'], dtype=object)

# %% [markdown]
# #### Drop

# %%
data_2.drop([3,5])
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19
# 4     5    asha    TE  63.28   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
data_2.drop('class', axis = 1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
data_2.drop(0, axis = 0)
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
data_2.drop('age', axis=1, inplace = True)
data_2
# Out:
#    roll     name class  marks
# 0     1     anil    TE  56.77
# 1     2     amit    TE  59.77
# 2     3   aniket    BE  76.88
# 3     4  ajinkya    TE  69.66
# 4     5     asha    TE  63.28
# 5     6   ayesha    BE  49.55
# 6     7     amar    BE  65.34
# 7     8    amita    BE  68.33
# 8     9     amol    TE  56.75
# 9    10    anmol    BE  78.66

# %%
data_2['marks'].add_suffix(23)
# Out:
# 023    56.77
# 123    59.77
# 223    76.88
# 323    69.66
# 423    63.28
# 523    49.55
# 623    65.34
# 723    68.33
# 823    56.75
# 923    78.66
# Name: marks, dtype: float64

# %%
data_2['marks'].median()
# Out:
# 64.31

# %%
data_n = pd.read_csv('Datasets/Students/student.csv')

# %%
data_n
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
data_n.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %%
data_n['marks'].median()
# Out:
# 64.31

# %%
data_n.sum(numeric_only=True)
# Out:
# roll      55.00
# marks    644.99
# age      205.00
# dtype: float64

# %%
data_n.mean(numeric_only=True)
# Out:
# roll      5.500
# marks    64.499
# age      20.500
# dtype: float64

# %%
import matplotlib.pyplot as plt
x = data_n['name']
y = data_n['age']

# %%
x, y
# Out:
# (0       anil
#  1       amit
#  2     aniket
#  3    ajinkya
#  4       asha
#  5     ayesha
#  6       amar
#  7      amita
#  8       amol
#  9      anmol
#  Name: name, dtype: object,
#  0    22
#  1    21
#  2    19
#  3    20
#  4    20
#  5    20
#  6    19
#  7    23
#  8    20
#  9    21
#  Name: age, dtype: int64)

# %%
plt.xlabel('Name')
plt.ylabel('Age')
plt.
plt.plot(x, y)
# Out:
#   Cell In[331], line 3
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
data_n['class'].value_counts()

# %%
data_n.sort_values('marks')

# %%
data_n.sort_values(['class', 'marks'], ascending=False)

# %% [markdown]
# ### Custom Column Operations

# %%
data_n['marks']+5

# %%
data_n['cgpa'] = data_n['marks']//10

# %%
# data_n['roll','name', 'marks', 'cgpa', 'age']

# %% [markdown]
# ##### Extra Coloumn Created

# %%
data_n['First Class'] = data_n['marks']>60

# %%
data_n

# %%
data_n['roll']
#for i in range(int(data_n['roll'])):
 #   print(i)

# %%
ndf = pd.DataFrame({
    'roll':range(1,11),
    'cgpa':data_n['marks']/10+0.034,
    'gender':['M', 'F', 'M', 'F', 'M', 'M', 'F', 'M', 'F', 'M']
})

ndf

# %%
df = pd.read_csv('Datasets/Students/student.csv')
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
ndf.columns
# Out:
# Index(['roll', 'cgpa', 'gender'], dtype='object')

# %%
df['roll']=ndf['roll']

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %% [markdown]
# # Join Merge
# # Append Concat

# %%
df.merge(ndf, on='roll')
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  56.77   22  5.711      M
# 1     2     amit    TE  59.77   21  6.011      F
# 2     3   aniket    BE  76.88   19  7.722      M
# 3     4  ajinkya    TE  69.66   20  7.000      F
# 4     5     asha    TE  63.28   20  6.362      M
# 5     6   ayesha    BE  49.55   20  4.989      M
# 6     7     amar    BE  65.34   19  6.568      F
# 7     8    amita    BE  68.33   23  6.867      M
# 8     9     amol    TE  56.75   20  5.709      F
# 9    10    anmol    BE  78.66   21  7.900      M

# %%
df5 = pd.read_csv('Datasets/Students/student5.csv')
df5
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([data_n, df], ignore_index=True)
# Out:
#     roll     name class  marks  age
# 0      1     anil    TE  56.77   22
# 1      2     amit    TE  59.77   21
# 2      3   aniket    BE  76.88   19
# 3      4  ajinkya    TE  69.66   20
# 4      5     asha    TE  63.28   20
# 5      6   ayesha    BE  49.55   20
# 6      7     amar    BE  65.34   19
# 7      8    amita    BE  68.33   23
# 8      9     amol    TE  56.75   20
# 9     10    anmol    BE  78.66   21
# 10     1     anil    TE  56.77   22
# 11     2     amit    TE  59.77   21
# 12     3   aniket    BE  76.88   19
# 13     4  ajinkya    TE  69.66   20
# 14     5     asha    TE  63.28   20
# 15     6   ayesha    BE  49.55   20
# 16     7     amar    BE  65.34   19
# 17     8    amita    BE  68.33   23
# 18     9     amol    TE  56.75   20
# 19    10    anmol    BE  78.66   21

# %% [markdown]
# # String Operations

# %%
Name = "sumit, Sumit"
Name
# Out:
# 'sumit, Sumit'

# %%
Name.count('Sumit')
# Out:
# 1

# %%
Name.encode()
# Out:
# b'sumit, Sumit'

# %% [markdown]
# ### Grouping and Aggregation

# %%
gr = df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('TE').max()
# Out:
# roll         9
# name      asha
# class       TE
# marks    69.66
# age         22
# dtype: object

# %%
gr.min()
# Out:
#        roll     name  marks  age
# class
# BE        3     amar  49.55   19
# TE        1  ajinkya  56.75   20

# %%
gr.describe()
# Out:
#        roll                                          marks          ...  \
#       count mean       std  min  25%  50%  75%   max count    mean  ...
# class                                                               ...
# BE      5.0  6.8  2.588436  3.0  6.0  7.0  8.0  10.0   5.0  67.752  ...
# TE      5.0  4.2  3.114482  1.0  2.0  4.0  5.0   9.0   5.0  61.246  ...
#
#                       age
#          75%    max count  mean       std   min   25%   50%   75%   max
# class
# BE     76.88  78.66   5.0  20.4  1.673320  19.0  19.0  20.0  21.0  23.0
# TE     63.28  69.66   5.0  20.6  0.894427  20.0  20.0  20.0  21.0  22.0
#
# [2 rows x 24 columns]

# %%
gr['marks'].max()
# Out:
# class
# BE    78.66
# TE    69.66
# Name: marks, dtype: float64

# %% [markdown]
# ### Boolean Filter

# %%
x = df[(df['marks]>60]) & (df['class'] == 'BE']
# Out:
#   Cell In[351], line 1
#     x = df[(df['marks]>60]) & (df['class'] == 'BE']
#                                                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
x = df[df['name'].str.startswith('an')]

# %%
x.to_html('Datasets/output.html', index=False)
