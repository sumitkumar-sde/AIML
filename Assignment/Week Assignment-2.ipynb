# %%
import pandas as pd
import matplotlib.pyplot
import numpy as np

# %%
#Data Location: https://mitu.co.in/dataset fb.csv

# %%
# Load the Data
df_fb = pd.read_csv('../Datasets/fb.csv')

# %%
df_fb
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# ### 1. Count how many number of posts are paid and unpaid?

# %%
# Total Post
total_post=len(df_fb)
total_post
# Out:
# 500

# %%
#Create mask for paid Post
df_fb['Paid']>0
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Paid, Length: 500, dtype: bool

# %%
# Apply the mask for total Paid Post
total_paid_post = len(df_fb[df_fb['Paid']>0])
total_unpaid_post = total_post -total_paid_post

# %%
print("Number of post are Paid :", total_paid_post)
print("Number of post are unpaid :", total_unpaid_post)
# Out:
# Number of post are Paid : 139
# Number of post are unpaid : 361

# %% [markdown]
# ### 2. Display only Page type, Month, like, comments and shares.

# %%
df_fb[['Type','Post Month','like','comment','share']]
# Out:
#        Type  Post Month    like  comment  share
# 0     Photo          12    79.0        4   17.0
# 1    Status          12   130.0        5   29.0
# 2     Photo          12    66.0        0   14.0
# 3     Photo          12  1572.0       58  147.0
# 4     Photo          12   325.0       19   49.0
# ..      ...         ...     ...      ...    ...
# 495   Photo           1    53.0        5   26.0
# 496   Photo           1    53.0        0   22.0
# 497   Photo           1    93.0        4   18.0
# 498   Photo           1    91.0        7   38.0
# 499   Photo           1    91.0        0   28.0
#
# [500 rows x 5 columns]

# %% [markdown]
# ### 3. Find average number of likes to the post in September month.

# %%
df_fb.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
# Create mask to filterout the september month df
df_fb['Post Month']==9
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Post Month, Length: 500, dtype: bool

# %%
# Apply the filter and get sum of like and total number of post
total_post = df_fb[df_fb['Post Month']==9].count()

# %% [markdown]
# ### 4. Find the information about the posts which are links.

# %%
???????
# Out:
# Object `?????` not found.

# %% [markdown]
# ### 5. How many total shares are present for the video posts?

# %%
# Create a mask for Data Type Video
df_fb['Type']=='Video'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Type, Length: 500, dtype: bool

# %%
# Apply the mask to DataFrame
df_fb[df_fb['Type'] == 'Video']
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
total_share = df_fb[df_fb['Type'] == 'Video']['share'].sum()
print("Total Number of share for Video Post = ", total_share)
# Out:
# Total Number of share for Video Post =  365.0

# %% [markdown]
# ### 6. In which hour of the day maximum post are posted?

# %%
#Know the 
print('Hours for Maximum post :',df_fb['Post Hour'].max())
# Out:
# Hours for Maximum post : 23

# %% [markdown]
# ### 7. In which day of October, maximum number of interactions are found?

# %%
#Create Mask
df_fb['Post Month']==10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Post Month, Length: 500, dtype: bool

# %%
#Apply The Mask
oct = df_fb[df_fb['Post Month']==10]

# %%
# Record the maximum number of intrection
oct.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
print("Maximum Number of Interaction for oct Month :",oct['Total Interactions'].max())
# Out:
# Maximum Number of Interaction for oct Month : 1626

# %% [markdown]
# ### 8. Print the information of the posts where likes are above 200 and shares are above 30.

# %%
#Create the Mask for like and apply to dataFrames
like_df = df_fb[df_fb['like']>200]

#Create the Mask for share on above and apply to dataFrames
like_df[like_df['share']>30]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 26             138458  Status         2          12             5         11
# 28             138895   Photo         2          12             5          3
# 38             138895  Status         2          12             7          9
# ..                ...     ...       ...         ...           ...        ...
# 464             92079   Photo         1           2             6         13
# 468             91651   Photo         1           2             4         12
# 476             86909   Photo         1           1             6         10
# 480             86909   Photo         2           1             4         11
# 488             85979   Photo         3           1             7         10
#
# ...
