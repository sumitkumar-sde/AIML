# %% [markdown]
# #### Dataset Image: sachin.jpg
# #### Location: https://mitu/co.in/dataset

# %% [markdown]
# ### 1. Apply following transformations on the image.

# %% [markdown]
# #### 1.1 Translate the image towards right by 400 and up by 150 pixels.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the Image using cv2
img = cv2.imread('../images/sachin.jpg')

# %%
# Convert the image from BGR to RGB
img_plt = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(16,9))
plt.imshow(img_plt)

# %%
# extract height and width of the image
height, width = img_plt.shape[:2]
height, width
# Out:
# (1075, 850)

# %%
# Image Translation
T = np.float32([[1, 0, 400], [0, 1, -150]])
T
# Out:
# array([[   1.,    0.,  400.],
#        [   0.,    1., -150.]], dtype=float32)

# %%
img_translation = cv2.warpAffine(
